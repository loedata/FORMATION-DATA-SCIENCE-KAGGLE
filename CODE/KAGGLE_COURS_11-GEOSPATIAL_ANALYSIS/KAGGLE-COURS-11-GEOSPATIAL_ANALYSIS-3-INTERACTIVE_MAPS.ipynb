# %% [markdown]
# # 11. GEOSPATIAL ANALYSIS

# %% [markdown]
# # 11.3. Interactive Maps

# %% [markdown]
# # 11.3.1. COURS

# %%
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster

# %%
# Create a map
# location sets the initial center of the map. We use the latitude (42.32° N) 
# and longitude (-71.0589° E) of the city of Boston.
m_1 = folium.Map(location=[42.32,-71.0589], tiles='openstreetmap', 
                 zoom_start=10)

# Display the map
m_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_2 = folium.Map(location=[42.32,-71.0589], tiles='cartodbdark_matter', 
                 zoom_start=10)

# Display the map
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_3 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', 
                 zoom_start=10)

# Display the map
m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_4 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositronnolabels', 
                 zoom_start=10)

# Display the map
m_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_5 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositrononlylabels', 
                 zoom_start=10)

# Display the map
m_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_6 = folium.Map(location=[42.32,-71.0589], tiles='stamenterrain', 
                 zoom_start=10)

# Display the map
m_6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_7 = folium.Map(location=[42.32,-71.0589], tiles='stamentoner', 
                 zoom_start=10)

# Display the map
m_7
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_8 = folium.Map(location=[42.32,-71.0589], tiles='stamentonerbackground', 
                 zoom_start=10)

# Display the map
m_8
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_9 = folium.Map(location=[42.32,-71.0589], tiles='stamentonerlabels', 
                 zoom_start=10)

# Display the map
m_9
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# Create a map
m_10 = folium.Map(location=[42.32,-71.0589], tiles='stamenwatercolor', 
                 zoom_start=10)

# Display the map
m_10
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # The data

# %%
# Chemin des sources
import os
os.chdir('C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_11-GEOSPATIAL_ANALYSIS')

# %%
import pandas as pd
import math

# %%
# Load the data
crimes = pd.read_csv("geospatial-learn-course-data/input/crimes-in-boston/crime.csv", encoding='latin-1')

# Drop rows with missing locations
crimes.dropna(subset=['Lat', 'Long', 'DISTRICT'], inplace=True)

# Focus on major crimes in 2018
crimes = crimes[crimes.OFFENSE_CODE_GROUP.isin([
    'Larceny', 'Auto Theft', 'Robbery', 'Larceny From Motor Vehicle', 'Residential Burglary',
    'Simple Assault', 'Harassment', 'Ballistics', 'Aggravated Assault', 'Other Burglary', 
    'Arson', 'Commercial Burglary', 'HOME INVASION', 'Homicide', 'Criminal Harassment', 
    'Manslaughter'])]
crimes = crimes[crimes.YEAR>=2018]

# Print the first five rows of the table
crimes.head()
# Out:
#    INCIDENT_NUMBER  OFFENSE_CODE          OFFENSE_CODE_GROUP  \
# 0       I182070945           619                     Larceny
# 6       I182070933           724                  Auto Theft
# 8       I182070931           301                     Robbery
# 19      I182070915           614  Larceny From Motor Vehicle
# 24      I182070908           522        Residential Burglary
#
#                       OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 0                      LARCENY ALL OTHERS      D14            808      NaN
# 6                              AUTO THEFT       B2            330      NaN
# 8                        ROBBERY - STREET       C6            177      NaN
# 19  LARCENY THEFT FROM MV - NON-ACCESSORY       B2            181      NaN
# 24      BURGLARY - RESIDENTIAL - NO FORCE       B2            911      NaN
#
#        OCCURRED_ON_DATE  YEAR  MONTH DAY_OF_WEEK  HOUR  UCR_PART  \
# 0   2018-09-02 13:00:00  2018      9      Sunday    13  Part One
# ...

# %% [markdown]
# # Plotting points

# %%
daytime_robberies = crimes[((crimes.OFFENSE_CODE_GROUP == 'Robbery') & \
                            (crimes.HOUR.isin(range(9,18))))]
print(type(daytime_robberies))
daytime_robberies
# Out:
# <class 'pandas.core.frame.DataFrame'>
#        INCIDENT_NUMBER  OFFENSE_CODE OFFENSE_CODE_GROUP  \
# 299         I182070598           311            Robbery
# 527         I182070342           381            Robbery
# 562         I182070309           361            Robbery
# 1127        I182069693           301            Robbery
# 1135        I182069687           301            Robbery
# ...                ...           ...                ...
# 66122       I182000161           311            Robbery
# 104826      I172066565           301            Robbery
# 174627      I162098332           361            Robbery
# 174629      I162098332           301            Robbery
# 181223      I162091188           301            Robbery
#
#           OFFENSE_DESCRIPTION DISTRICT REPORTING_AREA SHOOTING  \
# 299      ROBBERY - COMMERCIAL      A15             60      NaN
# 527     ROBBERY - CAR JACKING      E18            490      NaN
# ...

# %% [markdown]
# # folium.Marker

# %%
m_2 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
for idx, row in daytime_robberies.iterrows():
    Marker([row['Lat'], row['Long']]).add_to(m_2)

# Display the map
m_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # folium.plugins.MarkerCluster

# %%
m_3 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

# Add points to the map
mc = MarkerCluster()
for idx, row in daytime_robberies.iterrows():
    if not math.isnan(row['Long']) and not math.isnan(row['Lat']):
        mc.add_child(Marker([row['Lat'], row['Long']]))
m_3.add_child(mc)

# Display the map
m_3
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Bubble maps

# %%
# Create a base map
m_4 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=13)

def color_producer(val):
    if val <= 12:
        return 'forestgreen'
    else:
        return 'darkred'

# Add a bubble map to the base map
for i in range(0,len(daytime_robberies)):
    Circle(
        location=[daytime_robberies.iloc[i]['Lat'], daytime_robberies.iloc[i]['Long']],
        radius=20,
        color=color_producer(daytime_robberies.iloc[i]['HOUR'])).add_to(m_4)

# Display the map
m_4
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Heatmaps

# %%
# Create a base map
m_5 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=12)

# Add a heatmap to the base map
HeatMap(data=crimes[['Lat', 'Long']], radius=10).add_to(m_5)

# Display the map
m_5
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Choropleth maps

# %%
import geopandas as gpd
import pandas as pd
import matplotlib.pyplot as plt

# %%
# GeoDataFrame with geographical boundaries of Boston police districts
districts_full = gpd.read_file('geospatial-learn-course-data/input/crimes-in-boston/Police_Districts.shp')
districts = districts_full[["DISTRICT", "geometry"]].set_index("DISTRICT")
districts.head()
# Out:
#                                                    geometry
# DISTRICT
# A15       MULTIPOLYGON (((-71.07416 42.39051, -71.07415 ...
# A7        MULTIPOLYGON (((-70.99644 42.39557, -70.99644 ...
# A1        POLYGON ((-71.05200 42.36884, -71.05169 42.368...
# C6        POLYGON ((-71.04406 42.35403, -71.04412 42.353...
# D4        POLYGON ((-71.07416 42.35724, -71.07359 42.357...

# %%
# Number of crimes in each police district
plot_dict = crimes.DISTRICT.value_counts()
plot_dict.head()
# Out:
# D4     2885
# B2     2231
# A1     2130
# C11    1899
# B3     1421
# Name: DISTRICT, dtype: int64

# %%
# Create a base map
m_6 = folium.Map(location=[42.32,-71.0589], tiles='cartodbpositron', zoom_start=12)

# Add a choropleth map to the base map
Choropleth(geo_data=districts.__geo_interface__, 
           data=plot_dict, 
           key_on="feature.id", 
           fill_color='YlGnBu', 
           legend_name='Major criminal incidents (Jan-Aug 2018)'
          ).add_to(m_6)

# Display the map
m_6
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # 11.3.2. EXERCICES

# %%
import pandas as pd
import geopandas as gpd

import folium
from folium import Choropleth
from folium.plugins import HeatMap

# %%
def embed_map(m, file_name):
    from IPython.display import IFrame
    m.save(file_name)
    return IFrame(file_name, width='100%', height='500px')

# %% [markdown]
# # 1) Do earthquakes coincide with plate boundaries?

# %%
plate_boundaries = gpd.read_file("geospatial-learn-course-data/input/Plate_Boundaries/Plate_Boundaries.shp")
plate_boundaries['coordinates'] = plate_boundaries.apply(lambda x: [(b,a) for (a,b) in list(x.geometry.coords)], axis='columns')
plate_boundaries.drop('geometry', axis=1, inplace=True)

plate_boundaries.head()
# Out:
#   HAZ_PLATES                                         HAZ_PLAT_1  HAZ_PLAT_2  \
# 0     TRENCH                              SERAM TROUGH (ACTIVE)        6722
# 1     TRENCH                                       WETAR THRUST        6722
# 2     TRENCH  TRENCH WEST OF LUZON (MANILA TRENCH) NORTHERN ...        6621
# 3     TRENCH                                       BONIN TRENCH        9821
# 4     TRENCH                                  NEW GUINEA TRENCH        8001
#
#    Shape_Leng                                        coordinates
# 0    5.843467  [(-5.444200361999947, 133.6808931800001), (-5....
# 1    1.829013  [(-7.760600482999962, 125.47879802900002), (-7...
# 2    6.743604  [(19.817899819000047, 120.09999798800004), (19...
# 3    8.329381  [(26.175899215000072, 143.20620700100005), (26...
# 4   11.998145  [(0.41880004000006466, 132.8273013480001), (0....

# %%
# Load the data and print the first 5 rows
earthquakes = pd.read_csv("geospatial-learn-course-data/input/Plate_Boundaries/earthquakes1970-2014.csv", parse_dates=["DateTime"])
earthquakes.head()
# Out:
#                  DateTime  Latitude  Longitude  Depth  Magnitude MagType  \
# 0 1970-01-04 17:00:40.200    24.139    102.503   31.0        7.5      Ms
# 1 1970-01-06 05:35:51.800    -9.628    151.458    8.0        6.2      Ms
# 2 1970-01-08 17:12:39.100   -34.741    178.568  179.0        6.1      Mb
# 3 1970-01-10 12:07:08.600     6.825    126.737   73.0        6.1      Mb
# 4 1970-01-16 08:05:39.000    60.280   -152.660   85.0        6.0      ML
#
#    NbStations  Gap  Distance  RMS Source       EventID
# 0        90.0  NaN       NaN  0.0    NEI  1.970010e+09
# 1        85.0  NaN       NaN  0.0    NEI  1.970011e+09
# 2        59.0  NaN       NaN  0.0    NEI  1.970011e+09
# 3        91.0  NaN       NaN  0.0    NEI  1.970011e+09
# 4         0.0  NaN       NaN  NaN     AK           NaN

# %%
# Create a base map with plate boundaries
m_1 = folium.Map(location=[35,136], tiles='cartodbpositron', zoom_start=5)
for i in range(len(plate_boundaries)):
    folium.PolyLine(locations=plate_boundaries.coordinates.iloc[i], weight=2, 
                    color='black').add_to(m_1)

# Your code here: Add a heatmap to the map
HeatMap(data=earthquakes[['Latitude', 'Longitude']], radius=15).add_to(m_1)

# Show the map
embed_map(m_1, 'q_1.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="q_1.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 2) Is there a relationship between earthquake depth and proximity to a plate boundary in Japan?

# %%
earthquakes.describe()
# Out:
#          Latitude    Longitude        Depth    Magnitude   NbStations  \
# count  5304.00000  5304.000000  5304.000000  5304.000000  5250.000000
# mean      2.59036    44.641225    74.268037     6.369114   301.773905
# std      29.87294   124.792032   129.092258     0.419054   170.958824
# min     -66.44800  -179.989000     0.000000     6.000000     0.000000
# 25%     -17.73525   -73.653500    14.500000     6.100000   161.000000
# 50%      -3.49300   118.355500    33.000000     6.200000   289.500000
# 75%      28.17175   146.994500    52.300000     6.500000   424.000000
# max      84.94800   179.998000   688.000000     9.100000   934.000000
#
#               Gap    Distance          RMS       EventID
# count  172.000000  170.000000  5264.000000  5.242000e+03
# mean    49.098837    6.605882     0.816926  1.980309e+09
# std     52.888126   10.032667     0.559682  1.697093e+08
# min      0.000000    0.000000     0.000000  9.000000e+00
# ...

# %%
earthquakes.columns
# Out:
# Index(['DateTime', 'Latitude', 'Longitude', 'Depth', 'Magnitude', 'MagType',
#        'NbStations', 'Gap', 'Distance', 'RMS', 'Source', 'EventID'],
#       dtype='object')

# %%
# Create a base map with plate boundaries
m_2 = folium.Map(location=[35,136], tiles='cartodbpositron', zoom_start=5)
for i in range(len(plate_boundaries)):
    folium.PolyLine(locations=plate_boundaries.coordinates.iloc[i], weight=2, color='black').add_to(m_2)
    
# Your code here: Add a map to visualize earthquake depth
def color_producer(val):
    if val <= 52:
        return 'forestgreen'
    elif val <100 : 
        return 'darkorange'
    else:
        return 'darkred'

# Add a bubble map to the base map
for i in range(0,len(earthquakes)):
    folium.Circle(
        location=[earthquakes.iloc[i]['Latitude'], earthquakes.iloc[i]['Longitude']],
        radius=20,
        color=color_producer(earthquakes.iloc[i]['Depth'])).add_to(m_2)

# View the map
embed_map(m_2, 'q_2.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="q_2.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 3) Which prefectures have high population density?

# %%
# GeoDataFrame with prefecture boundaries
prefectures = gpd.read_file("geospatial-learn-course-data/input/japan-prefecture-boundaries/japan-prefecture-boundaries.shp")
prefectures.set_index('prefecture', inplace=True)
prefectures.head()
# Out:
#                                                      geometry
# prefecture
# Aichi       MULTIPOLYGON (((137.09523 34.65330, 137.09546 ...
# Akita       MULTIPOLYGON (((139.55725 39.20330, 139.55765 ...
# Aomori      MULTIPOLYGON (((141.39860 40.92472, 141.39806 ...
# Chiba       MULTIPOLYGON (((139.82488 34.98967, 139.82434 ...
# Ehime       MULTIPOLYGON (((132.55859 32.91224, 132.55904 ...

# %%
# DataFrame containing population of each prefecture
population = pd.read_csv("geospatial-learn-course-data/input/japan-prefecture-boundaries/japan-prefecture-population.csv")
population.set_index('prefecture', inplace=True)

# Calculate area (in square kilometers) of each prefecture
area_sqkm = pd.Series(prefectures.geometry.to_crs(epsg=32654).area / 10**6, name='area_sqkm')
stats = population.join(area_sqkm)

# Add density (per square kilometer) of each prefecture
stats['density'] = stats["population"] / stats["area_sqkm"]
stats.head()
# Out:
#             population    area_sqkm      density
# prefecture
# Tokyo         12868000  1800.614782  7146.448049
# Kanagawa       8943000  2383.038975  3752.771186
# Osaka          8801000  1923.151529  4576.342460
# Aichi          7418000  5164.400005  1436.372085
# Saitama        7130000  3794.036890  1879.264806

# %%
# Create a base map
m_3 = folium.Map(location=[35,136], tiles='cartodbpositron', zoom_start=5)

# Your code here: create a choropleth map to visualize population density

# Add a choropleth map to the base map
Choropleth(geo_data=prefectures['geometry'].__geo_interface__, 
           data=stats['density'], 
           key_on="feature.id", 
           fill_color='YlGnBu', 
           legend_name='Densité de population (par kilomètre carré) par préfecture du Japon'
          ).add_to(m_3)

# View the map
embed_map(m_3, 'q_3.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="q_3.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # 4) Which high-density prefecture is prone to high-magnitude earthquakes?

# %%
# Create a base map
m_4 = folium.Map(location=[35,136], tiles='cartodbpositron', zoom_start=5)

# Your code here: create a map
# Create a map
def color_producer(magnitude):
    if magnitude > 6.5:
        return 'red'
    else:
        return 'green'

Choropleth(
    geo_data=prefectures['geometry'].__geo_interface__,
    data=stats['density'],
    key_on="feature.id",
    fill_color='BuPu',
    legend_name='Population density (per square kilometer)').add_to(m_4)

for i in range(0,len(earthquakes)):
    folium.Circle(
        location=[earthquakes.iloc[i]['Latitude'], earthquakes.iloc[i]['Longitude']],
        popup=("{} ({})").format(
            earthquakes.iloc[i]['Magnitude'],
            earthquakes.iloc[i]['DateTime'].year),
        radius=earthquakes.iloc[i]['Magnitude']**5.5,
        color=color_producer(earthquakes.iloc[i]['Magnitude'])).add_to(m_4)

# View the map
embed_map(m_4, 'q_4.html')
# Out:
#         <iframe
#             width="100%"
#             height="500px"
#             src="q_4.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
