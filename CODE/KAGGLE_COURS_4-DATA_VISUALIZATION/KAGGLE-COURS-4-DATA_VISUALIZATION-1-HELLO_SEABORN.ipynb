# %% [markdown]
# # 4 - DATA VISUALIZATION

# %% [markdown]
# # 4.1. HELLO, SEABORN

# %%
# Chargement des librairies
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#  astuce pour afficher toutes les lignes sans les ...
pd.set_option('display.max_row', 80)
#  astuce pour afficher toutes les colonnes dans les head()
pd.set_option('display.max_column', 80)

# %% [markdown]
# ## CHARGEMENT DES DATASETS FULL ET TEST

# %%
# Chargement des datasets
fifa_filepath = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_4-DATA_VISUALIZATION/'
fifa_data = pd.read_csv(fifa_filepath + 'data_for_datavis/input/fifa.csv', 
                index_col="Date", parse_dates=True)

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,12))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)
plt.show()

# %%
# Which lines stay at least five consecutive years at the bottom of the
# chart?
# The only country that meets this criterion is Brazil (code: BRA), as it   
# maintains the highest ranking in 1996-2000. Other countries do spend some
# time in the number 1 spot, but Brazil is the only country that maintains
# it for at least five consecutive years.
