# %% [markdown]
# # 4 - DATA VISUALIZATION

# %% [markdown]
# # 4.4. SCATTER PLOTS

# %%
# Chargement des librairies
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#  astuce pour afficher toutes les lignes sans les ...
pd.set_option('display.max_row', 80)
#  astuce pour afficher toutes les colonnes dans les head()
pd.set_option('display.max_column', 80)

# %% [markdown]
# # 4.4.1. COURS

# %% [markdown]
# ## CHARGEMENT DES DATASETS

# %%
# Chargement des datasets
insurance_filepath = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_4-DATA_VISUALIZATION/'
insurance_data = pd.read_csv(insurance_filepath + 'data_for_datavis/input/insurance.csv')

# %%
#  5 premières lignes
insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ## SCATTER PLOTS

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'])
plt.show()

# %%
# couleur en fonction d'une autre variable ==> fumeur par exemple
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'],
               hue=insurance_data['smoker'])
plt.show()

# %% [markdown]
# ## REGRESSION LINEAIRE : VOIR RELATIONS ENTRE VARIABLES

# %% [markdown]
# ## REGPLOT

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'])
plt.show()

# %% [markdown]
# ## LMPLOT

# %%
#  voir si les fumeurs paient plus?
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data)
plt.show()
# hypothèse : vérifiée

# %% [markdown]
# ## CATEGORICAL PLOT

# %% [markdown]
# ## SWARMPLOT

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])
plt.show()
# Out:
# C:\Users\Outils\lib\site-packages\seaborn\categorical.py:1296: UserWarning: 67.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# # 4.4.2. EXERCICES

# %% [markdown]
# ## CHARGEMENT DES DATASETS

# %%
# Chargement des datasets
candy_filepath = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_4-DATA_VISUALIZATION/'
candy_data = pd.read_csv(candy_filepath + 'data_for_datavis/input/candy.csv')

# %%
candy_data.head()
# Out:
#    id competitorname chocolate fruity caramel peanutyalmondy nougat  \
# 0   0      100 Grand       Yes     No     Yes             No     No
# 1   1   3 Musketeers       Yes     No      No             No    Yes
# 2   2      Air Heads        No    Yes      No             No     No
# 3   3     Almond Joy       Yes     No      No            Yes     No
# 4   4      Baby Ruth       Yes     No     Yes            Yes    Yes
#
#   crispedricewafer hard  bar pluribus  sugarpercent  pricepercent  winpercent
# 0              Yes   No  Yes       No         0.732         0.860   66.971725
# 1               No   No  Yes       No         0.604         0.511   67.602936
# 2               No   No   No       No         0.906         0.511   52.341465
# 3               No   No  Yes       No         0.465         0.767   50.347546
# 4               No   No  Yes       No         0.604         0.767   56.914547

# %%
candy_data[['competitorname','sugarpercent']].head()
# Out:
#   competitorname  sugarpercent
# 0      100 Grand         0.732
# 1   3 Musketeers         0.604
# 2      Air Heads         0.906
# 3     Almond Joy         0.465
# 4      Baby Ruth         0.604

# %% [markdown]
# ## SCATTER PLOT

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
plt.show()

# %%
# Solution: The scatter plot does not show a strong correlation between the 
# two variables. Since there is no clear relationship between the two 
# variables, this tells us that sugar content does not play a strong role in
# candy popularity.

# %% [markdown]
# ## REGPLOT

# %%
sns.regplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'])
plt.show()

# %%
# Solution: Since the regression line has a slightly positive slope, this 
# tells us that there is a slightly positive correlation between 'winpercent'
# and 'sugarpercent'. Thus, people have a slight preference for candies 
# containing relatively more sugar.

# %% [markdown]
# ## SCATTER PLOT EN FONCTION AUTRE VARIABLE CHOCOLAT

# %%
sns.scatterplot(x=candy_data['sugarpercent'], y=candy_data['winpercent'],
               hue=candy_data['chocolate'])
plt.show()

# %% [markdown]
# ## LMPLOT / relation entre les variables?

# %%
sns.lmplot(x="pricepercent", y="winpercent", hue="chocolate",
           data=candy_data)
plt.show()

# %%
# Solution: We'll begin with the regression line for chocolate candies. 
# Since this line has a slightly positive slope, we can say that more 
# expensive chocolate candies tend to be more popular (than relatively 
# cheaper chocolate candies). 
# Likewise, since the regression line for candies without chocolate has a 
# negative slope, we can say that if candies don't contain chocolate, they 
# tend to be more popular when they are cheaper. One important note, however,
# is that the dataset is quite small -- so we shouldn't invest too much 
# trust in these patterns! To inspire more confidence in the results, 
# we should add more candies to the dataset.

# %%
sns.swarmplot(x=candy_data['chocolate'],
              y=candy_data['winpercent'])
plt.show()

# %%
# Solution: In this case, the categorical scatter plot from Step 7 is the
# more appropriate plot. While both plots tell the desired story, the plot 
# from Step 6 conveys far more information that could distract from the main 
# point.
