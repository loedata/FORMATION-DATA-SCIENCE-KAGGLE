# %% [markdown]
# # 4 - DATA VISUALIZATION

# %% [markdown]
# # 4.7. FINAL PROJECT

# %%
# Chargement des librairies
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#  astuce pour afficher toutes les lignes sans les ...
pd.set_option('display.max_row', 80)
#  astuce pour afficher toutes les colonnes dans les head()
pd.set_option('display.max_column', 80)

# %% [markdown]
# ## CHARGEMENT DES DATASETS

# %%
# Chargement des datasets
comic_filepath = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_4-DATA_VISUALIZATION/'
comic_data = pd.read_csv(comic_filepath + 'comics/input/marvel-wikia-data.csv', 
                index_col='page_id')

# %% [markdown]
# ## LINEPLOT

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,12))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=comic_data)
plt.show()

# %% [markdown]
# ## SCATTERPLOT

# %%
sns.scatterplot(x=comic_data['Year'], y=comic_data['APPEARANCES'])
plt.show()
