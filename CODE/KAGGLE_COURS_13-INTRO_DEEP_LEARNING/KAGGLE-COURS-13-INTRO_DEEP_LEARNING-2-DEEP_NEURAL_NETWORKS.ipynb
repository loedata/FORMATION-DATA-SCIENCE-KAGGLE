# %% [markdown]
# # 13. INTRODUCTION DEEP LEARNING

# %% [markdown]
# # 13.2. Deep Neural Networks

# %% [markdown]
# # 13.2.1. COURS

# %% [markdown]
# # Building Sequential Models

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=4, activation='relu', input_shape=[2]),
    layers.Dense(units=3, activation='relu'),
    # the linear output layer 
    layers.Dense(units=1),
])

# %% [markdown]
# # 13.2.2. EXERCICES

# %%
# Chemin des sources
import os
os.chdir('C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_13-INTRO_DEEP_LEARNING/input')

# %%
import tensorflow as tf

# Setup plotting
import matplotlib.pyplot as plt

plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)

# %%
import pandas as pd

concrete = pd.read_csv('concrete.csv')
concrete.head()
# Out:
#    Cement  BlastFurnaceSlag  FlyAsh  Water  Superplasticizer  CoarseAggregate  \
# 0   540.0               0.0     0.0  162.0               2.5           1040.0
# 1   540.0               0.0     0.0  162.0               2.5           1055.0
# 2   332.5             142.5     0.0  228.0               0.0            932.0
# 3   332.5             142.5     0.0  228.0               0.0            932.0
# 4   198.6             132.4     0.0  192.0               0.0            978.4
#
#    FineAggregate  Age  CompressiveStrength
# 0          676.0   28                79.99
# 1          676.0   28                61.89
# 2          594.0  270                40.27
# 3          594.0  365                41.05
# 4          825.5  360                44.30

# %% [markdown]
# # 1) Input Shape

# %%
# L'objectif de cette tâche est la colonne "Résistance à la compression". 
# Les autres colonnes sont les caractéristiques que nous utiliserons comme 
# intrants.

# %%
concrete.shape
# Out:
# (1030, 9)

# %%
input_shape = [8]

# %% [markdown]
# # 2) Define a Model with Hidden Layers

# %%
# Créez maintenant un modèle avec trois couches cachées, chacune ayant 512 
# unités et l'activation ReLU. 
# Veillez à inclure une couche de sortie d'une unité et sans activation, ainsi
# que input_shape comme argument de la première couche.
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE
model = keras.Sequential([
    # the hidden ReLU layers
    layers.Dense(units=512, activation='relu', input_shape=input_shape),
    layers.Dense(units=512, activation='relu'),
    layers.Dense(units=512, activation='relu'),
    # the linear output layer 
    layers.Dense(units=1),
])

# %% [markdown]
# # 3) Activation Layers

# %%
# Réécrivez le modèle suivant pour que chaque activation se trouve dans sa 
# propre couche d'activation.
model = keras.Sequential([
    layers.Dense(32, input_shape=[8]),
    layers.Activation('relu'),
    layers.Dense(32),
    layers.Activation('relu'),
    layers.Dense(1),
])

# %% [markdown]
# # Optional: Alternatives to ReLU

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
activation_layer = layers.Activation('relu')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
activation_layer = layers.Activation('elu')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
activation_layer = layers.Activation('selu')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
activation_layer = layers.Activation('swish')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, 
# softplus, softsign,  tanh, softmax
activation_layer = layers.Activation('exponential')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, 
# softplus, softsign,  tanh, softmax
activation_layer = layers.Activation('linear')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, softplus, 
# softsign, tanh, softmax
activation_layer = layers.Activation('hard_sigmoid')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, softplus, 
# softsign, tanh, softmax
activation_layer = layers.Activation('sigmoid')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, softplus, 
# softsign, tanh, softmax
activation_layer = layers.Activation('softplus')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, softplus, 
# softsign, tanh, softmax
activation_layer = layers.Activation('softsign')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()

# %%
# YOUR CODE HERE: Change 'relu' to 'elu', 'selu', 'swish'... or something else
# relu, elu,selu, swish, exponential, linear, hard_sigmoid, sigmoid, softplus, 
# softsign, tanh, softmax
activation_layer = layers.Activation('tanh')

x = tf.linspace(-3.0, 3.0, 100)
y = activation_layer(x) # once created, a layer is callable just like a function

plt.figure(dpi=100)
plt.plot(x, y)
plt.xlim(-3, 3)
plt.xlabel("Input")
plt.ylabel("Output")
plt.show()
