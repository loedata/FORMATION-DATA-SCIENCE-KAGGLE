# %% [markdown]
# # 5. PANDAS

# %% [markdown]
# # 5.6. RENAMING AND COMBINING

# %%
# Chargement des librairies
import pandas as pd

# %%
#  astuce pour afficher toutes les lignes sans les ...
pd.set_option('display.max_row', 80)
#  astuce pour afficher toutes les colonnes dans les head()
pd.set_option('display.max_column', 80)

# %%
# charger un dataset avec un colonne index non nommée
reviews_path = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_5-PANDAS/wine-reviews/input/'
reviews = pd.read_csv(reviews_path + 'winemag-data-130k-v2.csv', 
                      index_col=0)

# %% [markdown]
# # 5.6.1. COURS

# %% [markdown]
# ## RENAMING

# %% [markdown]
# ## RENAME()

# %% [markdown]
# ### rename(columns=)

# %%
# renommer le nom d'une colonne du dataframe
reviews.rename(columns={'points': 'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  score  price  \
# 0                                 Vulkà Bianco     87    NaN
# ...

# %% [markdown]
# ### rename(index=) PLUTOT UTILSER : set_index()

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# A NE PAS UTILISER ==> utiliser plutôt set_index()
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# 2                  US  Tart and snappy, the flavors of lime flesh and...
# 3                  US  Pineapple rind, lemon pith and orange blossom ...
# 4                  US  Much like the regular bottling from 2012, this...
# ...               ...                                                ...
# 129966        Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967             US  Citation is given as much as a decade of bottl...
# 129968         France  Well-drained gravel soil gives this wine its c...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                         designation  points  price  \
# ...

# %% [markdown]
# ## RENAME_AXIS('nom_lignes' , axis='rows')
# ## RENAME_AXIS('nom_colonnes' , axis='columns')

# %%
# on peut donner un nom aux colonnes et aux lignes
reviews.rename_axis("wines", axis='rows').rename_axis("fields", axis='columns')
# Out:
# fields   country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# fields                             designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ## COMBINING PLUSIEURS DATAFRAME

# %%
# charger un dataset avec un colonne index non nommée
# path = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_5-PANDAS/youtube-new/input/'
# canadian_youtube = pd.read_csv(path + 'CAvideos.csv')
# british_youtube = pd.read_csv(path + 'GBvideos.csv')

# %% [markdown]
# ## CONCAT()

# %%
# df_ca_gb = pd.concat([canadian_youtube, british_youtube])
# df_ca_gb.head()

# %%
# canadian_youtube.head()

# %% [markdown]
# ## JOIN()

# %%
# left = canadian_youtube.set_index(['title', 'trending_date'])
# right = british_youtube.set_index(['title', 'trending_date'])
# left.join(right, lsuffix='_CAN', rsuffix='_UK')

# %% [markdown]
# # 5.6.2. EXERCICES

# %%
# charger un dataset avec un colonne index non nommée
reviews_path = 'C:/Users/PC Maison/4-KAGGLE/KAGGLE_DEV/KAGGLE_COURS_5-PANDAS/wine-reviews/input/'
reviews = pd.read_csv(reviews_path + 'winemag-data-130k-v2.csv', 
                      index_col=0)

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %% [markdown]
# ## RENAME(columns= )

# %%
# renommer region_1 en region et region_2 en locale
renamed = reviews.rename(columns={'region_1': 'region',
                                  'region_2': 'locale'})
renamed
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
# renommer le nom des index du dataframe en wines
reindexed = reviews.rename_axis("wines", axis='rows')
reindexed
# Out:
#          country                                        description  \
# wines
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# wines
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# ## CONCAT()

# %%
gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
gaming_products['subreddit'] = "r/gaming"
movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
movie_products['subreddit'] = "r/movies"
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-18-2e4ce42583c6> in <module>
# ----> 1 gaming_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/g/gaming.csv")
#       2 gaming_products['subreddit'] = "r/gaming"
#       3 movie_products = pd.read_csv("../input/things-on-reddit/top-things/top-things/reddits/m/movies.csv")
#       4 movie_products['subreddit'] = "r/movies"
#
# ...

# %%
combined_products = pd.concat([gaming_products, movie_products])

# %% [markdown]
# ## JOIN()

# %%
powerlifting_meets = pd.read_csv("../input/powerlifting-database/meets.csv")
powerlifting_competitors = pd.read_csv("../input/powerlifting-database/openpowerlifting.csv")

# %%
powerlifting_combined = powerlifting_meets.set_index("MeetID").join(powerlifting_competitors.set_index("MeetID"))
